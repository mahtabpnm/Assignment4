# %% [markdown]
# 1. PCA and NMF: PCA actually reduce the data with directions which max the varience and can have negative values. NMF reduces data as well but only for non negative
# 2. Actually good initilization avoid any unstable gredient and help to work faster
# 3. how can we prevent overfitiing is with using dropout and regularization, data augmentation or we can use larger dataset
# 4. CNN by filter can detect the image pater but MLP trat and train all input same without thinking of spitial relationship.
# 5. To vanish problems in gredient we can use sigmoid, which gradient become very little and and hard to update the older layers for the network
# 6. ResNEt make grediants pass through directly wirh skiiping the connection and also solve the vanishing gredient issue

# %% [markdown]
# To Summary what I have done Q1: I added RandomHorizontalFlip() to flip the images by random. Then I added randomCrop to introduce variability in the training data. Then I added Dropout layer with p=0.5 to connect completely without overfitting. then I used Steplr to adjust the learning data with reducing by 5 ephchs. I also added optimizer to with SGD momentum to improve and make it faster.

# %%
import os
import time

import numpy as np
import pandas as pd

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader

from torchvision import datasets
from torchvision import transforms

import matplotlib.pyplot as plt
from PIL import Image


if torch.cuda.is_available():
    torch.backends.cudnn.deterministic = True

# %%
##########################
### SETTINGS
##########################

# Hyperparameters
RANDOM_SEED = 1
LEARNING_RATE = 0.001
BATCH_SIZE = 128
NUM_EPOCHS = 20

# Architecture
NUM_FEATURES = 32*32
NUM_CLASSES = 10

# Other
if torch.cuda.is_available():
    DEVICE = "cuda:0"
else:
    DEVICE = "cpu"

GRAYSCALE = False

# %%
##########################
### CIFAR-10 Dataset
##########################

train_mean = (0.5, 0.5, 0.5)
train_std = (0.5, 0.5, 0.5)

# Adding data augmentation for training to reduce overfitting
resize_transform = transforms.Compose([
    transforms.RandomHorizontalFlip(),  # Random horizontal flip
    transforms.RandomCrop(32, padding=4),  # Random crop
    transforms.ToTensor(),  # Convert to PyTorch tensors
    transforms.Normalize(train_mean, train_std)  # Normalize
])

# Transform for test data (no augmentation)
test_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(train_mean, train_std)  # Normalize
])

# Datasets
train_dataset = datasets.CIFAR10(root='data', 
                                 train=True, 
                                 transform=resize_transform,
                                 download=True)

test_dataset = datasets.CIFAR10(root='data', 
                                train=False, 
                                transform=test_transform)

# Data loaders
train_loader = DataLoader(dataset=train_dataset, 
                          batch_size=BATCH_SIZE, 
                          num_workers=8,
                          shuffle=True)

test_loader = DataLoader(dataset=test_dataset, 
                         batch_size=BATCH_SIZE,
                         num_workers=8,
                         shuffle=False)

# Checking the dataset
for images, labels in train_loader:  
    print('Image batch dimensions:', images.shape)
    print('Image label dimensions:', labels.shape)
    break

for images, labels in train_loader:  
    print('Image batch dimensions:', images.shape)
    print('Image label dimensions:', labels.shape)
    break
# Out:
# Files already downloaded and verified
# Image batch dimensions: torch.Size([128, 3, 32, 32])
# Image label dimensions: torch.Size([128])
# Image batch dimensions: torch.Size([128, 3, 32, 32])
# Image label dimensions: torch.Size([128])

# %%
device = torch.device(DEVICE)
torch.manual_seed(0)

for epoch in range(2):

    for batch_idx, (x, y) in enumerate(train_loader):
        
        print('Epoch Num:', epoch+1, end='')
        print(' | Batches Inx:', batch_idx, end='')
        print(' | The Size of Batch:', y.size()[0])
        
        x = x.to(device)
        y = y.to(device)
# Out:
# Epoch Num: 1 | Batches Inx: 0 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 1 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 2 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 3 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 4 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 5 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 6 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 7 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 8 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 9 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 10 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 11 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 12 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 13 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 14 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 15 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 16 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 17 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 18 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 19 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 20 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 21 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 22 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 23 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 24 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 25 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 26 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 27 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 28 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 29 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 30 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 31 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 32 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 33 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 34 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 35 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 36 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 37 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 38 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 39 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 40 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 41 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 42 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 43 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 44 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 45 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 46 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 47 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 48 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 49 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 50 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 51 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 52 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 53 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 54 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 55 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 56 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 57 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 58 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 59 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 60 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 61 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 62 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 63 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 64 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 65 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 66 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 67 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 68 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 69 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 70 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 71 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 72 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 73 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 74 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 75 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 76 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 77 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 78 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 79 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 80 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 81 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 82 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 83 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 84 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 85 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 86 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 87 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 88 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 89 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 90 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 91 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 92 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 93 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 94 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 95 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 96 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 97 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 98 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 99 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 100 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 101 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 102 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 103 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 104 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 105 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 106 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 107 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 108 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 109 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 110 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 111 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 112 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 113 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 114 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 115 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 116 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 117 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 118 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 119 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 120 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 121 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 122 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 123 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 124 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 125 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 126 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 127 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 128 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 129 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 130 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 131 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 132 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 133 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 134 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 135 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 136 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 137 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 138 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 139 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 140 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 141 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 142 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 143 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 144 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 145 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 146 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 147 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 148 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 149 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 150 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 151 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 152 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 153 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 154 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 155 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 156 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 157 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 158 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 159 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 160 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 161 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 162 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 163 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 164 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 165 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 166 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 167 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 168 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 169 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 170 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 171 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 172 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 173 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 174 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 175 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 176 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 177 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 178 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 179 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 180 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 181 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 182 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 183 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 184 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 185 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 186 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 187 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 188 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 189 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 190 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 191 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 192 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 193 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 194 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 195 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 196 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 197 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 198 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 199 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 200 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 201 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 202 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 203 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 204 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 205 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 206 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 207 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 208 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 209 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 210 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 211 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 212 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 213 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 214 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 215 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 216 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 217 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 218 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 219 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 220 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 221 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 222 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 223 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 224 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 225 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 226 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 227 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 228 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 229 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 230 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 231 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 232 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 233 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 234 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 235 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 236 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 237 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 238 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 239 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 240 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 241 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 242 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 243 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 244 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 245 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 246 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 247 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 248 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 249 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 250 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 251 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 252 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 253 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 254 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 255 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 256 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 257 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 258 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 259 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 260 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 261 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 262 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 263 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 264 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 265 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 266 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 267 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 268 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 269 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 270 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 271 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 272 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 273 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 274 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 275 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 276 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 277 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 278 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 279 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 280 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 281 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 282 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 283 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 284 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 285 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 286 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 287 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 288 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 289 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 290 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 291 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 292 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 293 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 294 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 295 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 296 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 297 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 298 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 299 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 300 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 301 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 302 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 303 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 304 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 305 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 306 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 307 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 308 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 309 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 310 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 311 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 312 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 313 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 314 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 315 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 316 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 317 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 318 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 319 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 320 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 321 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 322 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 323 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 324 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 325 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 326 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 327 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 328 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 329 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 330 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 331 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 332 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 333 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 334 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 335 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 336 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 337 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 338 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 339 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 340 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 341 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 342 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 343 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 344 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 345 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 346 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 347 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 348 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 349 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 350 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 351 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 352 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 353 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 354 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 355 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 356 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 357 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 358 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 359 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 360 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 361 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 362 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 363 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 364 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 365 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 366 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 367 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 368 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 369 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 370 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 371 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 372 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 373 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 374 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 375 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 376 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 377 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 378 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 379 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 380 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 381 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 382 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 383 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 384 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 385 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 386 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 387 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 388 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 389 | The Size of Batch: 128
# Epoch Num: 1 | Batches Inx: 390 | The Size of Batch: 80

# %%
class LeNet5(nn.Module):

    def __init__(self, num_classes, grayscale=False):
        super(LeNet5, self).__init__()
        
        self.grayscale = grayscale
        self.num_classes = num_classes

        if self.grayscale:
            in_channels = 1  # Indented properly
        else:
            in_channels = 3  # Indented properly

        # Feature extractor part
        self.features = nn.Sequential(
            nn.Conv2d(in_channels, 6*in_channels, kernel_size=5),  # First convolution
            nn.ReLU(),  # ReLU activation function
            nn.MaxPool2d(kernel_size=2),  # First pooling layer
            nn.Conv2d(6*in_channels, 16*in_channels, kernel_size=5),  # Second convolution
            nn.ReLU(),  # ReLU activation function
            nn.MaxPool2d(kernel_size=2)  # Second pooling layer
        )
        
        # Classifier part
        self.classifier = nn.Sequential(
            nn.Linear(16*5*5*in_channels, 256),  # Increased size for fully connected layer 1
            nn.ReLU(),  # ReLU activation for better learning
            nn.Dropout(p=0.5),  # Dropout for regularization
            nn.Linear(256, 128),  # Increased size for fully connected layer 2
            nn.ReLU(),  # ReLU activation
            nn.Dropout(p=0.5),  # Dropout for regularization
            nn.Linear(128, num_classes)  # Output layer
        )

    def forward(self, x):
        x = self.features(x)  # Pass through feature extractor
        x = torch.flatten(x, 1)  # Flatten for fully connected layers
        logits = self.classifier(x)  # Pass through the classifier
        probas = F.softmax(logits, dim=1)  # Apply softmax for probabilities
        return logits, probas

# %%
torch.manual_seed(RANDOM_SEED)

model = LeNet5(NUM_CLASSES, GRAYSCALE)
model.to(DEVICE)

optimizer = torch.optim.SGD(model.parameters(), lr=0.001, momentum=0.9)

scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=5, gamma=0.1)
#the line in the top is for addinf schedular

# %%
def compute_accuracy(model, data_loader, device):
    correct_pred, num_examples = 0, 0
    for i, (features, targets) in enumerate(data_loader):
        features = features.to(device)
        targets = targets.to(device)

        logits, probas = model(features)
        _, predicted_labels = torch.max(probas, 1)
        num_examples += targets.size(0)
        correct_pred += (predicted_labels == targets).sum()
    return correct_pred.float() / num_examples * 100


start_time = time.time()
for epoch in range(NUM_EPOCHS):
    model.train()
    for batch_idx, (features, targets) in enumerate(train_loader):
        features = features.to(DEVICE)
        targets = targets.to(DEVICE)
        
        # Forward pass and compute the loss
        logits, probas = model(features)
        cost = F.cross_entropy(logits, targets)
        optimizer.zero_grad()
        
        # Backward pass and update model parameters
        cost.backward()
        optimizer.step()
        
        # Logging every 50 batches
        if not batch_idx % 50:
            print('Epoch are becoming: %03d/%03d | And Batch have become %04d/%04d | This is Cost: %.4f' 
                  % (epoch + 1, NUM_EPOCHS, batch_idx, len(train_loader), cost))
    
    # Step the learning rate scheduler at the end of each epoch
    scheduler.step()

    # Evaluate model on the training set
    model.eval()
    with torch.set_grad_enabled(False):  # save memory during inference
        print('Epoches are: %03d/%03d | With Training: %.3f%%' % (
              epoch + 1, NUM_EPOCHS, 
              compute_accuracy(model, train_loader, device=DEVICE)))
    
    print('The Time Elapsed: %.2f min' % ((time.time() - start_time) / 60))

print('Output the total training time: %.2f min' % ((time.time() - start_time) / 60))

# %%
with torch.set_grad_enabled(False): # save memory during inference
    print('Test accuracy: %.2f%%' % (compute_accuracy(model, test_loader, device=DEVICE)))

# %%
class UnNormalize(object):
    def __init__(self, mean, std):
        self.mean = mean
        self.std = std

    def __call__(self, tensor):
        """
        Parameters:
        ------------
        tensor (Tensor): Tensor image of size (C, H, W) to be normalized.
        
        Returns:
        ------------
        Tensor: Normalized image.

        """
        for t, m, s in zip(tensor, self.mean, self.std):
            t.mul_(s).add_(m)
        return tensor
    
unorm = UnNormalize(mean=train_mean, std=train_std)

# %%
test_loader = DataLoader(dataset=train_dataset, 
                         batch_size=BATCH_SIZE, 
                         shuffle=True)

for features, targets in test_loader:
    break
    

_, predictions = model.forward(features[:8].to(DEVICE))
predictions = torch.argmax(predictions, dim=1)

d = {0: 'airplane',
     1: 'automobile',
     2: 'bird',
     3: 'cat',
     4: 'deer',
     5: 'dog',
     6: 'frog',
     7: 'horse',
     8: 'ship',
     9: 'truck'}
    
fig, ax = plt.subplots(1, 8, figsize=(20, 10))
for i in range(8):
    img = unorm(features[i])
    ax[i].imshow(np.transpose(img, (1, 2, 0)))
    ax[i].set_xlabel(d[predictions[i].item()])

plt.show()
